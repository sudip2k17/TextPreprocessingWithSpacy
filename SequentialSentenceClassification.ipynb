# %% [markdown]
# <a href="https://colab.research.google.com/github/sudip2k17/TextPreprocessingWithSpacy/blob/main/SequentialSentenceClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sequential Sentence Classification Project**
#
# **Objective**: Build a deep learning model for sequential sentence classification to convert "harder to read" text into "easier to read" text.

# %% [markdown]
# Model Overview
#
# 1. Baseline Model: Naïve Bayes + TF-IDF
# 2. Deep Learning Models:
#
#
# *   Conv1D with Token Embedding
# *   Pretrained Feature Extractor (GloVe, FastText)
# *   Conv1D with Character Embedding
# *   LLM-Based Approach (BERT as Feature Extractor)

# %% [markdown]
# Step 1: Install & Import Dependencies

# %%
# !pip install transformers datasets torch tensorflow keras nltk spacy
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Collecting datasets
#   Downloading datasets-3.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (3.8.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.7.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.12)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.10.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Downloading datasets-3.3.2-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 9.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 11.8 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.4 MB/s eta 0:00:00
# Installing collected packages: xxhash, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed datasets-3.3.2 dill-0.3.8 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 xxhash-3.5.0

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import torch
import nltk
import spacy

from transformers import BertTokenizer, BertModel
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Input
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, Dataset

# %% [markdown]
# Step 2: Load & Preprocess Data (PubMed 20k RCT)

# %%
# Define dataset paths
train_path = "/content/dataset/train.txt"
test_path = "/content/dataset/test.txt"

# Function to load dataset
def load_pubmed_dataset(file_path):
    sentences = []
    labels = []
    with open(file_path, "r", encoding="utf-8") as file:
        for line in file.readlines():
            line = line.strip()
            if not line:
                continue  # Skip empty lines

            parts = line.split("\t", maxsplit=1)  # Ensure only first tab is used for splitting
            if len(parts) == 2:
                label, sentence = parts
                sentences.append(sentence.strip())
                labels.append(label.strip())
            else:
                print(f"Skipping malformed line: {line}")  # Log issue instead of crashing
    return sentences, labels

# Load data
train_sentences, train_labels = load_pubmed_dataset(train_path)
test_sentences, test_labels = load_pubmed_dataset(test_path)

# Encode labels
label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)
test_labels_encoded = label_encoder.transform(test_labels)

label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label Mapping:", label_mapping)
# Out:
# Streaming output truncated to the last 5000 lines.
# Skipping malformed line: ###25098442
# Skipping malformed line: ###25180378
# Skipping malformed line: ###25273342
# Skipping malformed line: ###25123822
# Skipping malformed line: ###25007362
# Skipping malformed line: ###25057878
# Skipping malformed line: ###25145377
# Skipping malformed line: ###24379169
# Skipping malformed line: ###25533222
# Skipping malformed line: ###24755566
# Skipping malformed line: ###24599566
# Skipping malformed line: ###24274342
# Skipping malformed line: ###25467394
# Skipping malformed line: ###24608624
# Skipping malformed line: ###24356937
# Skipping malformed line: ###26442396
# Skipping malformed line: ###24981503
# Skipping malformed line: ###24475799
# Skipping malformed line: ###24998293
# Skipping malformed line: ###24918555
# Skipping malformed line: ###24290781
# Skipping malformed line: ###24229669
# Skipping malformed line: ###25175176
# Skipping malformed line: ###24579804
# Skipping malformed line: ###25666010
# Skipping malformed line: ###24738695
# Skipping malformed line: ###25459040
# Skipping malformed line: ###24357798
# Skipping malformed line: ###25070400
# Skipping malformed line: ###24697877
# Skipping malformed line: ###24755056
# Skipping malformed line: ###25343945
# Skipping malformed line: ###26200232
# Skipping malformed line: ###25539512
# Skipping malformed line: ###24445089
# Skipping malformed line: ###24752228
# Skipping malformed line: ###25770879
# Skipping malformed line: ###24944140
# Skipping malformed line: ###24462230
# Skipping malformed line: ###25124938
# Skipping malformed line: ###25156527
# Skipping malformed line: ###25039678
# Skipping malformed line: ###25591469
# Skipping malformed line: ###25458786
# Skipping malformed line: ###24630479
# Skipping malformed line: ###24509986
# Skipping malformed line: ###24764339
# Skipping malformed line: ###25296654
# Skipping malformed line: ###24424433
# Skipping malformed line: ###25240704
# Skipping malformed line: ###24493666
# Skipping malformed line: ###25383780
# Skipping malformed line: ###24998009
# Skipping malformed line: ###24694983
# Skipping malformed line: ###24721127
# Skipping malformed line: ###24319686
# Skipping malformed line: ###24708857
# Skipping malformed line: ###25879721
# Skipping malformed line: ###24401752
# Skipping malformed line: ###25644856
# Skipping malformed line: ###24507553
# Skipping malformed line: ###25530148
# Skipping malformed line: ###25629790
# Skipping malformed line: ###24814607
# Skipping malformed line: ###24245778
# Skipping malformed line: ###24499830
# Skipping malformed line: ###24496960
# Skipping malformed line: ###24587006
# Skipping malformed line: ###25533966
# Skipping malformed line: ###25305763
# Skipping malformed line: ###25855884
# Skipping malformed line: ###25563312
# Skipping malformed line: ###25686117
# Skipping malformed line: ###26095784
# Skipping malformed line: ###25328464
# Skipping malformed line: ###24565240
# Skipping malformed line: ###24532276
# Skipping malformed line: ###24585363
# Skipping malformed line: ###26087214
# Skipping malformed line: ###24502830
# Skipping malformed line: ###24257892
# Skipping malformed line: ###24664811
# Skipping malformed line: ###25766269
# Skipping malformed line: ###25092938
# Skipping malformed line: ###25627152
# Skipping malformed line: ###25151662
# Skipping malformed line: ###25004184
# Skipping malformed line: ###24831252
# Skipping malformed line: ###25053420
# Skipping malformed line: ###24251693
# Skipping malformed line: ###25530364
# Skipping malformed line: ###25688780
# Skipping malformed line: ###25219207
# Skipping malformed line: ###24308613
# Skipping malformed line: ###25007865
# Skipping malformed line: ###24966134
# Skipping malformed line: ###25200141
# Skipping malformed line: ###24965700
# Skipping malformed line: ###24740868
# Skipping malformed line: ###24687744
# Skipping malformed line: ###25590292
# Skipping malformed line: ###25150004
# Skipping malformed line: ###24867313
# Skipping malformed line: ###24570217
# Skipping malformed line: ###24390871
# Skipping malformed line: ###24677406
# Skipping malformed line: ###24933798
# Skipping malformed line: ###24361543
# Skipping malformed line: ###24461572
# Skipping malformed line: ###24603308
# Skipping malformed line: ###24574125
# Skipping malformed line: ###25679343
# Skipping malformed line: ###24519100
# Skipping malformed line: ###25137523
# Skipping malformed line: ###24985938
# Skipping malformed line: ###25417401
# Skipping malformed line: ###24678758
# Skipping malformed line: ###24904204
# Skipping malformed line: ###24574869
# Skipping malformed line: ###24704684
# Skipping malformed line: ###25420010
# Skipping malformed line: ###24338186
# Skipping malformed line: ###25112695
# Skipping malformed line: ###25187584
# Skipping malformed line: ###25131925
# Skipping malformed line: ###25695061
# Skipping malformed line: ###26027630
# Skipping malformed line: ###24254885
# Skipping malformed line: ###25509731
# Skipping malformed line: ###24281283
# Skipping malformed line: ###24266596
# Skipping malformed line: ###24347766
# Skipping malformed line: ###25315207
# Skipping malformed line: ###25797743
# Skipping malformed line: ###25007689
# Skipping malformed line: ###24345886
# Skipping malformed line: ###24572255
# Skipping malformed line: ###24589938
# Skipping malformed line: ###25873046
# Skipping malformed line: ###24354833
# Skipping malformed line: ###25029426
# Skipping malformed line: ###24597619
# Skipping malformed line: ###24874782
# Skipping malformed line: ###25035126
# Skipping malformed line: ###24852508
# Skipping malformed line: ###24411753
# Skipping malformed line: ###24661390
# Skipping malformed line: ###25425502
# Skipping malformed line: ###24734285
# Skipping malformed line: ###25216508
# Skipping malformed line: ###25170902
# Skipping malformed line: ###25487763
# Skipping malformed line: ###26026105
# Skipping malformed line: ###25062747
# Skipping malformed line: ###26062192
# Skipping malformed line: ###24745198
# Skipping malformed line: ###25629739
# Skipping malformed line: ###25095797
# Skipping malformed line: ###24450931
# Skipping malformed line: ###25322173
# Skipping malformed line: ###25358227
# Skipping malformed line: ###24281271
# Skipping malformed line: ###24915873
# Skipping malformed line: ###24512527
# Skipping malformed line: ###25130289
# Skipping malformed line: ###24280382
# Skipping malformed line: ###24576509
# Skipping malformed line: ###25319802
# Skipping malformed line: ###25464565
# Skipping malformed line: ###25172229
# Skipping malformed line: ###25345731
# Skipping malformed line: ###24929350
# Skipping malformed line: ###25573272
# Skipping malformed line: ###24625704
# Skipping malformed line: ###24716651
# Skipping malformed line: ###25248797
# Skipping malformed line: ###25223583
# Skipping malformed line: ###24906295
# Skipping malformed line: ###24445084
# Skipping malformed line: ###25509255
# Skipping malformed line: ###25169631
# Skipping malformed line: ###24867903
# Skipping malformed line: ###25854013
# Skipping malformed line: ###24421054
# Skipping malformed line: ###25344807
# Skipping malformed line: ###25533223
# Skipping malformed line: ###25453458
# Skipping malformed line: ###24248149
# Skipping malformed line: ###25049068
# Skipping malformed line: ###24957753
# Skipping malformed line: ###24376842
# Skipping malformed line: ###24741361
# Skipping malformed line: ###24323062
# Skipping malformed line: ###25306750
# Skipping malformed line: ###24649895
# Skipping malformed line: ###24608200
# Skipping malformed line: ###25403215
# Skipping malformed line: ###26244306
# Skipping malformed line: ###25212062
# Skipping malformed line: ###25567822
# Skipping malformed line: ###24806481
# Skipping malformed line: ###25573655
# Skipping malformed line: ###25332476
# Skipping malformed line: ###24586896
# Skipping malformed line: ###24890250
# Skipping malformed line: ###25615566
# Skipping malformed line: ###24858669
# Skipping malformed line: ###25251999
# Skipping malformed line: ###25783434
# Skipping malformed line: ###25263513
# Skipping malformed line: ###25293478
# Skipping malformed line: ###25937443
# Skipping malformed line: ###25525163
# Skipping malformed line: ###26075375
# Skipping malformed line: ###24306002
# Skipping malformed line: ###24268845
# Skipping malformed line: ###24725075
# Skipping malformed line: ###25596097
# Skipping malformed line: ###25545240
# Skipping malformed line: ###24690625
# Skipping malformed line: ###25054399
# Skipping malformed line: ###24521323
# Skipping malformed line: ###25117873
# Skipping malformed line: ###25213048
# Skipping malformed line: ###24381967
# Skipping malformed line: ###25033847
# Skipping malformed line: ###25415733
# Skipping malformed line: ###25074283
# Skipping malformed line: ###25274428
# Skipping malformed line: ###24719492
# Skipping malformed line: ###25414155
# Skipping malformed line: ###25753894
# Skipping malformed line: ###25256624
# Skipping malformed line: ###25197997
# Skipping malformed line: ###24531083
# Skipping malformed line: ###25442152
# Skipping malformed line: ###25153050
# Skipping malformed line: ###24881610
# Skipping malformed line: ###24462483
# Skipping malformed line: ###24269077
# Skipping malformed line: ###24748218
# Skipping malformed line: ###25997550
# Skipping malformed line: ###24970773
# Skipping malformed line: ###25090264
# Skipping malformed line: ###25549907
# Skipping malformed line: ###26031737
# Skipping malformed line: ###24413548
# Skipping malformed line: ###24249435
# Skipping malformed line: ###24885729
# Skipping malformed line: ###24692735
# Skipping malformed line: ###24776962
# Skipping malformed line: ###25288512
# Skipping malformed line: ###25428511
# Skipping malformed line: ###25816050
# Skipping malformed line: ###24752608
# Skipping malformed line: ###25749597
# Skipping malformed line: ###24754328
# Skipping malformed line: ###25707709
# Skipping malformed line: ###24226057
# Skipping malformed line: ###25609193
# Skipping malformed line: ###25416241
# Skipping malformed line: ###24503402
# Skipping malformed line: ###25271207
# Skipping malformed line: ###24622150
# Skipping malformed line: ###24460536
# Skipping malformed line: ###26052984
# Skipping malformed line: ###24814767
# Skipping malformed line: ###24433264
# Skipping malformed line: ###24793364
# Skipping malformed line: ###25185361
# Skipping malformed line: ###26028518
# Skipping malformed line: ###24916483
# Skipping malformed line: ###25452049
# Skipping malformed line: ###24967423
# Skipping malformed line: ###24519421
# Skipping malformed line: ###25287282
# Skipping malformed line: ###24791863
# Skipping malformed line: ###25406305
# Skipping malformed line: ###24504788
# Skipping malformed line: ###24509969
# Skipping malformed line: ###24507377
# Skipping malformed line: ###24360008
# Skipping malformed line: ###25822648
# Skipping malformed line: ###24253247
# Skipping malformed line: ###24284781
# Skipping malformed line: ###24378765
# Skipping malformed line: ###24417608
# Skipping malformed line: ###24281309
# Skipping malformed line: ###24230461
# Skipping malformed line: ###24909293
# Skipping malformed line: ###25957224
# Skipping malformed line: ###25241756
# Skipping malformed line: ###25318186
# Skipping malformed line: ###26488691
# Skipping malformed line: ###25125300
# Skipping malformed line: ###25169652
# Skipping malformed line: ###24324331
# Skipping malformed line: ###25187211
# Skipping malformed line: ###25327872
# Skipping malformed line: ###25981810
# Skipping malformed line: ###25004803
# Skipping malformed line: ###24334642
# Skipping malformed line: ###24389523
# Skipping malformed line: ###24612455
# Skipping malformed line: ###25632744
# Skipping malformed line: ###25112082
# Skipping malformed line: ###24528930
# Skipping malformed line: ###25218264
# Skipping malformed line: ###25265769
# Skipping malformed line: ###25439165
# Skipping malformed line: ###25155048
# Skipping malformed line: ###24840325
# Skipping malformed line: ###24733445
# Skipping malformed line: ###25651494
# Skipping malformed line: ###25678687
# Skipping malformed line: ###25740805
# Skipping malformed line: ###25605856
# Skipping malformed line: ###24809437
# Skipping malformed line: ###24498092
# Skipping malformed line: ###25948287
# Skipping malformed line: ###25208853
# Skipping malformed line: ###24313385
# Skipping malformed line: ###24228847
# Skipping malformed line: ###25283504
# Skipping malformed line: ###24558835
# Skipping malformed line: ###24951020
# Skipping malformed line: ###24252173
# Skipping malformed line: ###24398115
# Skipping malformed line: ###24931322
# Skipping malformed line: ###25581251
# Skipping malformed line: ###24363128
# Skipping malformed line: ###25605628
# Skipping malformed line: ###25060372
# Skipping malformed line: ###24786930
# Skipping malformed line: ###24378206
# Skipping malformed line: ###25365798
# Skipping malformed line: ###24585721
# Skipping malformed line: ###25138123
# Skipping malformed line: ###25552575
# Skipping malformed line: ###24812901
# Skipping malformed line: ###24607301
# Skipping malformed line: ###25264972
# Skipping malformed line: ###25266831
# Skipping malformed line: ###25624435
# Skipping malformed line: ###24519693
# Skipping malformed line: ###24841774
# Skipping malformed line: ###24248551
# Skipping malformed line: ###25137867
# Skipping malformed line: ###24286335
# Skipping malformed line: ###25004983
# Skipping malformed line: ###25490971
# Skipping malformed line: ###24316712
# Skipping malformed line: ###25112010
# Skipping malformed line: ###25795406
# Skipping malformed line: ###24679061
# Skipping malformed line: ###24655705
# Skipping malformed line: ###24310562
# Skipping malformed line: ###24468257
# Skipping malformed line: ###24602708
# Skipping malformed line: ###25624143
# Skipping malformed line: ###24499460
# Skipping malformed line: ###25254489
# Skipping malformed line: ###24261013
# Skipping malformed line: ###24678280
# Skipping malformed line: ###24859954
# Skipping malformed line: ###25688779
# Skipping malformed line: ###25439417
# Skipping malformed line: ###24894850
# Skipping malformed line: ###24934986
# Skipping malformed line: ###25251736
# Skipping malformed line: ###24767620
# Skipping malformed line: ###24437955
# Skipping malformed line: ###25456960
# Skipping malformed line: ###25315237
# Skipping malformed line: ###25492279
# Skipping malformed line: ###25475465
# Skipping malformed line: ###24534405
# Skipping malformed line: ###24690207
# Skipping malformed line: ###24927291
# Skipping malformed line: ###25418216
# Skipping malformed line: ###24965551
# Skipping malformed line: ###24228630
# Skipping malformed line: ###25092278
# Skipping malformed line: ###24560179
# Skipping malformed line: ###25111438
# Skipping malformed line: ###24461666
# Skipping malformed line: ###24369785
# Skipping malformed line: ###25126867
# Skipping malformed line: ###24886235
# Skipping malformed line: ###25249453
# Skipping malformed line: ###24518532
# Skipping malformed line: ###25047652
# Skipping malformed line: ###25673979
# Skipping malformed line: ###24811201
# Skipping malformed line: ###25022428
# Skipping malformed line: ###24245566
# Skipping malformed line: ###24681963
# Skipping malformed line: ###24300222
# Skipping malformed line: ###25188544
# Skipping malformed line: ###24559953
# Skipping malformed line: ###24617243
# Skipping malformed line: ###24903620
# Skipping malformed line: ###25865175
# Skipping malformed line: ###25332253
# Skipping malformed line: ###25577838
# Skipping malformed line: ###25287554
# Skipping malformed line: ###24698648
# Skipping malformed line: ###25807814
# Skipping malformed line: ###25681448
# Skipping malformed line: ###25794218
# Skipping malformed line: ###25068411
# Skipping malformed line: ###25300863
# Skipping malformed line: ###25769593
# Skipping malformed line: ###25173342
# Skipping malformed line: ###24875748
# Skipping malformed line: ###25395384
# Skipping malformed line: ###25440887
# Skipping malformed line: ###24635935
# Skipping malformed line: ###25179977
# Skipping malformed line: ###24666361
# Skipping malformed line: ###24447085
# Skipping malformed line: ###25885432
# Skipping malformed line: ###25068560
# Skipping malformed line: ###25146732
# Skipping malformed line: ###25367310
# Skipping malformed line: ###25472825
# Skipping malformed line: ###24685414
# Skipping malformed line: ###25456333
# Skipping malformed line: ###25127244
# Skipping malformed line: ###24395985
# Skipping malformed line: ###25417892
# Skipping malformed line: ###24832476
# Skipping malformed line: ###25377015
# Skipping malformed line: ###24576855
# Skipping malformed line: ###24796199
# Skipping malformed line: ###25542677
# Skipping malformed line: ###25273653
# Skipping malformed line: ###24465387
# Skipping malformed line: ###24700631
# Skipping malformed line: ###25710460
# Skipping malformed line: ###25440791
# Skipping malformed line: ###25301251
# Skipping malformed line: ###25225745
# Skipping malformed line: ###24771090
# Skipping malformed line: ###24622263
# Skipping malformed line: ###24519922
# Skipping malformed line: ###24902402
# Skipping malformed line: ###24331630
# Skipping malformed line: ###24294838
# Skipping malformed line: ###25072523
# Skipping malformed line: ###24722160
# Skipping malformed line: ###25370364
# Skipping malformed line: ###24852180
# Skipping malformed line: ###24708338
# Skipping malformed line: ###25225436
# Skipping malformed line: ###24755906
# Skipping malformed line: ###25555562
# Skipping malformed line: ###25581612
# Skipping malformed line: ###24862255
# Skipping malformed line: ###25266929
# Skipping malformed line: ###24987838
# Skipping malformed line: ###25218696
# Skipping malformed line: ###24972708
# Skipping malformed line: ###25210961
# Skipping malformed line: ###25719692
# Skipping malformed line: ###24415559
# Skipping malformed line: ###25193295
# Skipping malformed line: ###24254033
# Skipping malformed line: ###24400915
# Skipping malformed line: ###25399658
# Skipping malformed line: ###24332196
# Skipping malformed line: ###24239203
# Skipping malformed line: ###24619324
# Skipping malformed line: ###25499342
# Skipping malformed line: ###24661520
# Skipping malformed line: ###24296324
# Skipping malformed line: ###24372434
# Skipping malformed line: ###25881382
# Skipping malformed line: ###24342385
# Skipping malformed line: ###24630347
# Skipping malformed line: ###25270008
# Skipping malformed line: ###24419418
# Skipping malformed line: ###25703475
# Skipping malformed line: ###24875654
# Skipping malformed line: ###25886281
# Skipping malformed line: ###24486117
# Skipping malformed line: ###24246825
# Skipping malformed line: ###26018333
# Skipping malformed line: ###24938504
# Skipping malformed line: ###25155966
# Skipping malformed line: ###24879965
# Skipping malformed line: ###24970786
# Skipping malformed line: ###24622413
# Skipping malformed line: ###25892646
# Skipping malformed line: ###24598948
# Skipping malformed line: ###24523413
# Skipping malformed line: ###25413567
# Skipping malformed line: ###24783221
# Skipping malformed line: ###24456057
# Skipping malformed line: ###25332486
# Skipping malformed line: ###24322483
# Skipping malformed line: ###25138273
# Skipping malformed line: ###26289681
# Skipping malformed line: ###25541389
# Skipping malformed line: ###24907873
# Skipping malformed line: ###25844993
# Skipping malformed line: ###25361836
# Skipping malformed line: ###25141850
# Skipping malformed line: ###25109699
# Skipping malformed line: ###24726046
# Skipping malformed line: ###25344737
# Skipping malformed line: ###24361112
# Skipping malformed line: ###26125415
# Skipping malformed line: ###24667813
# Skipping malformed line: ###25322972
# Skipping malformed line: ###25363153
# Skipping malformed line: ###25886354
# Skipping malformed line: ###25243574
# Skipping malformed line: ###24598949
# Skipping malformed line: ###24894359
# Skipping malformed line: ###25018057
# Skipping malformed line: ###25358679
# Skipping malformed line: ###24474305
# Skipping malformed line: ###25582785
# Skipping malformed line: ###26241598
# Skipping malformed line: ###25710925
# Skipping malformed line: ###24300437
# Skipping malformed line: ###25346026
# Skipping malformed line: ###24373344
# Skipping malformed line: ###24449031
# Skipping malformed line: ###25043834
# Skipping malformed line: ###24594248
# Skipping malformed line: ###24998109
# Skipping malformed line: ###24360521
# Skipping malformed line: ###25406046
# Skipping malformed line: ###25820113
# Skipping malformed line: ###25427845
# Skipping malformed line: ###25296655
# Skipping malformed line: ###24925984
# Skipping malformed line: ###24252648
# Skipping malformed line: ###24473534
# Skipping malformed line: ###25049338
# Skipping malformed line: ###25034716
# Skipping malformed line: ###24789375
# Skipping malformed line: ###24610180
# Skipping malformed line: ###24784763
# Skipping malformed line: ###24456677
# Skipping malformed line: ###25012072
# Skipping malformed line: ###25160516
# Skipping malformed line: ###25632577
# Skipping malformed line: ###25208199
# Skipping malformed line: ###24428461
# Skipping malformed line: ###26337307
# Skipping malformed line: ###24399647
# Skipping malformed line: ###24411083
# Skipping malformed line: ###24643055
# Skipping malformed line: ###25699389
# Skipping malformed line: ###25138814
# Skipping malformed line: ###25205142
# Skipping malformed line: ###26211828
# Skipping malformed line: ###24379136
# Skipping malformed line: ###25478757
# Skipping malformed line: ###24618349
# Skipping malformed line: ###25934864
# Skipping malformed line: ###24231759
# Skipping malformed line: ###25760565
# Skipping malformed line: ###24899339
# Skipping malformed line: ###25375836
# Skipping malformed line: ###24943245
# Skipping malformed line: ###24738319
# Skipping malformed line: ###24815910
# Skipping malformed line: ###25245776
# Skipping malformed line: ###26307877
# Skipping malformed line: ###24447885
# Skipping malformed line: ###24938580
# Skipping malformed line: ###25146349
# Skipping malformed line: ###24928295
# Skipping malformed line: ###25414932
# Skipping malformed line: ###25348257
# Skipping malformed line: ###25153575
# Skipping malformed line: ###25354407
# Skipping malformed line: ###24970708
# Skipping malformed line: ###25618966
# Skipping malformed line: ###25660925
# Skipping malformed line: ###24627419
# Skipping malformed line: ###25402840
# Skipping malformed line: ###24277116
# Skipping malformed line: ###25877492
# Skipping malformed line: ###24357853
# Skipping malformed line: ###24556825
# Skipping malformed line: ###25534294
# Skipping malformed line: ###24785885
# Skipping malformed line: ###24287602
# Skipping malformed line: ###25093483
# Skipping malformed line: ###24279904
# Skipping malformed line: ###26466202
# Skipping malformed line: ###24687640
# Skipping malformed line: ###24445356
# Skipping malformed line: ###25684570
# Skipping malformed line: ###24820759
# Skipping malformed line: ###24320943
# Skipping malformed line: ###25709122
# Skipping malformed line: ###25064573
# Skipping malformed line: ###24725797
# Skipping malformed line: ###24939916
# Skipping malformed line: ###25129881
# Skipping malformed line: ###25305762
# Skipping malformed line: ###25287106
# Skipping malformed line: ###24954156
# Skipping malformed line: ###24643488
# Skipping malformed line: ###24754350
# Skipping malformed line: ###25086593
# Skipping malformed line: ###25381588
# Skipping malformed line: ###25150401
# Skipping malformed line: ###24456512
# Skipping malformed line: ###25456290
# Skipping malformed line: ###25512434
# Skipping malformed line: ###25022821
# Skipping malformed line: ###24470753
# Skipping malformed line: ###25236367
# Skipping malformed line: ###25582097
# Skipping malformed line: ###25665812
# Skipping malformed line: ###25736397
# Skipping malformed line: ###24872326
# Skipping malformed line: ###25182544
# Skipping malformed line: ###24742955
# Skipping malformed line: ###24503560
# Skipping malformed line: ###25942458
# Skipping malformed line: ###25138758
# Skipping malformed line: ###25822284
# Skipping malformed line: ###24411152
# Skipping malformed line: ###24982494
# Skipping malformed line: ###25241544
# Skipping malformed line: ###26086157
# Skipping malformed line: ###24378599
# Skipping malformed line: ###25566620
# Skipping malformed line: ###25891549
# Skipping malformed line: ###24760962
# Skipping malformed line: ###24673738
# Skipping malformed line: ###25143342
# Skipping malformed line: ###25227477
# Skipping malformed line: ###25060019
# Skipping malformed line: ###26267623
# Skipping malformed line: ###24416905
# Skipping malformed line: ###24616624
# Skipping malformed line: ###24939380
# Skipping malformed line: ###24333244
# Skipping malformed line: ###24814388
# Skipping malformed line: ###24980440
# Skipping malformed line: ###25082595
# Skipping malformed line: ###25406226
# Skipping malformed line: ###24756739
# Skipping malformed line: ###25135030
# Skipping malformed line: ###25264948
# Skipping malformed line: ###24885993
# Skipping malformed line: ###25412669
# Skipping malformed line: ###25131184
# Skipping malformed line: ###25442659
# Skipping malformed line: ###25524333
# Skipping malformed line: ###24326236
# Skipping malformed line: ###24678896
# Skipping malformed line: ###26001028
# Skipping malformed line: ###24486242
# Skipping malformed line: ###25701170
# Skipping malformed line: ###24424707
# Skipping malformed line: ###24444117
# Skipping malformed line: ###24722493
# Skipping malformed line: ###24361312
# Skipping malformed line: ###25450275
# Skipping malformed line: ###24587233
# Skipping malformed line: ###25027821
# Skipping malformed line: ###24717908
# Skipping malformed line: ###24720640
# Skipping malformed line: ###26255512
# Skipping malformed line: ###24427796
# Skipping malformed line: ###24331269
# Skipping malformed line: ###24550168
# Skipping malformed line: ###25754458
# Skipping malformed line: ###25137875
# Skipping malformed line: ###25514098
# Skipping malformed line: ###24825528
# Skipping malformed line: ###24481686
# Skipping malformed line: ###25271396
# Skipping malformed line: ###24961184
# Skipping malformed line: ###25071343
# Skipping malformed line: ###25536255
# Skipping malformed line: ###24875670
# Skipping malformed line: ###25290658
# Skipping malformed line: ###24340150
# Skipping malformed line: ###25017487
# Skipping malformed line: ###24239143
# Skipping malformed line: ###25728723
# Skipping malformed line: ###24450252
# Skipping malformed line: ###24439637
# Skipping malformed line: ###24432627
# Skipping malformed line: ###24969577
# Skipping malformed line: ###25266357
# Skipping malformed line: ###24339179
# Skipping malformed line: ###25395844
# Skipping malformed line: ###24512733
# Skipping malformed line: ###24743062
# Skipping malformed line: ###24556445
# Skipping malformed line: ###25699687
# Skipping malformed line: ###24315404
# Skipping malformed line: ###24393129
# Skipping malformed line: ###25162257
# Skipping malformed line: ###24617235
# Skipping malformed line: ###24345717
# Skipping malformed line: ###24439186
# Skipping malformed line: ###24364801
# Skipping malformed line: ###25428509
# Skipping malformed line: ###25567131
# Skipping malformed line: ###25609761
# Skipping malformed line: ###25267980
# Skipping malformed line: ###25226843
# Skipping malformed line: ###25662503
# Skipping malformed line: ###25269046
# Skipping malformed line: ###25567713
# Skipping malformed line: ###24889399
# Skipping malformed line: ###24950523
# Skipping malformed line: ###24536060
# Skipping malformed line: ###24742124
# Skipping malformed line: ###24427795
# Skipping malformed line: ###25740286
# Skipping malformed line: ###26258613
# Skipping malformed line: ###25523430
# Skipping malformed line: ###25445827
# Skipping malformed line: ###25619263
# Skipping malformed line: ###25920634
# Skipping malformed line: ###24308874
# Skipping malformed line: ###24434073
# Skipping malformed line: ###26290088
# Skipping malformed line: ###24429537
# Skipping malformed line: ###24452701
# Skipping malformed line: ###24477186
# Skipping malformed line: ###24384083
# Skipping malformed line: ###25682778
# Skipping malformed line: ###25888114
# Skipping malformed line: ###24621566
# Skipping malformed line: ###25435806
# Skipping malformed line: ###25063959
# Skipping malformed line: ###25678325
# Skipping malformed line: ###25891010
# Skipping malformed line: ###25096822
# Skipping malformed line: ###25922190
# Skipping malformed line: ###25073797
# Skipping malformed line: ###25327602
# Skipping malformed line: ###24998258
# Skipping malformed line: ###25140772
# Skipping malformed line: ###25623102
# Skipping malformed line: ###24232364
# Skipping malformed line: ###24623024
# Skipping malformed line: ###24229408
# Skipping malformed line: ###26283758
# Skipping malformed line: ###25644442
# Skipping malformed line: ###24330784
# Skipping malformed line: ###25746563
# Skipping malformed line: ###25136077
# Skipping malformed line: ###25793429
# Skipping malformed line: ###25842221
# Skipping malformed line: ###25495490
# Skipping malformed line: ###25255113
# Skipping malformed line: ###25762810
# Skipping malformed line: ###25032220
# Skipping malformed line: ###24619151
# Skipping malformed line: ###24931252
# Skipping malformed line: ###26461996
# Skipping malformed line: ###25675564
# Skipping malformed line: ###25884986
# Skipping malformed line: ###24660971
# Skipping malformed line: ###25536254
# Skipping malformed line: ###26268408
# Skipping malformed line: ###24888540
# Skipping malformed line: ###24253834
# Skipping malformed line: ###25554072
# Skipping malformed line: ###25391601
# Skipping malformed line: ###24814167
# Skipping malformed line: ###25499944
# Skipping malformed line: ###24640440
# Skipping malformed line: ###25300431
# Skipping malformed line: ###24341049
# Skipping malformed line: ###25074944
# Skipping malformed line: ###25989386
# Skipping malformed line: ###25841539
# Skipping malformed line: ###24633761
# Skipping malformed line: ###25486673
# Skipping malformed line: ###24908596
# Skipping malformed line: ###26095263
# Skipping malformed line: ###24660604
# Skipping malformed line: ###25227174
# Skipping malformed line: ###24628824
# Skipping malformed line: ###25932840
# Skipping malformed line: ###25675123
# Skipping malformed line: ###24637869
# Skipping malformed line: ###25940724
# Skipping malformed line: ###25345982
# Skipping malformed line: ###25667135
# Skipping malformed line: ###25240493
# Skipping malformed line: ###25217073
# Skipping malformed line: ###24506318
# Skipping malformed line: ###24884948
# Skipping malformed line: ###24725989
# Skipping malformed line: ###24357575
# Skipping malformed line: ###24962473
# Skipping malformed line: ###26255473
# Skipping malformed line: ###25920295
# Skipping malformed line: ###26042933
# Skipping malformed line: ###24588860
# Skipping malformed line: ###24991714
# Skipping malformed line: ###24457536
# Skipping malformed line: ###25005172
# Skipping malformed line: ###24560453
# Skipping malformed line: ###25168098
# Skipping malformed line: ###25625366
# Skipping malformed line: ###24270291
# Skipping malformed line: ###24961881
# Skipping malformed line: ###24906581
# Skipping malformed line: ###24509716
# Skipping malformed line: ###24636695
# Skipping malformed line: ###25742559
# Skipping malformed line: ###25740026
# Skipping malformed line: ###24452659
# Skipping malformed line: ###24566987
# Skipping malformed line: ###24439348
# Skipping malformed line: ###25142196
# Skipping malformed line: ###25460343
# Skipping malformed line: ###24473387
# Skipping malformed line: ###25262270
# Skipping malformed line: ###25217066
# Skipping malformed line: ###25376862
# Skipping malformed line: ###25049315
# Skipping malformed line: ###25148580
# Skipping malformed line: ###25277343
# Skipping malformed line: ###24836213
# Skipping malformed line: ###24947754
# Skipping malformed line: ###25414931
# Skipping malformed line: ###26154185
# Skipping malformed line: ###24473364
# Skipping malformed line: ###25148183
# Skipping malformed line: ###25596960
# Skipping malformed line: ###24465958
# Skipping malformed line: ###25010443
# Skipping malformed line: ###25597529
# Skipping malformed line: ###24227357
# Skipping malformed line: ###25562195
# Skipping malformed line: ###25719991
# Skipping malformed line: ###24290801
# Skipping malformed line: ###24410738
# Skipping malformed line: ###24921223
# Skipping malformed line: ###24988118
# Skipping malformed line: ###25316180
# Skipping malformed line: ###25030803
# Skipping malformed line: ###24614693
# Skipping malformed line: ###24432670
# Skipping malformed line: ###25269598
# Skipping malformed line: ###24568949
# Skipping malformed line: ###24269085
# Skipping malformed line: ###25123116
# Skipping malformed line: ###25332249
# Skipping malformed line: ###25156886
# Skipping malformed line: ###24506405
# Skipping malformed line: ###24535359
# Skipping malformed line: ###25082832
# Skipping malformed line: ###25833773
# Skipping malformed line: ###24506231
# Skipping malformed line: ###24622805
# Skipping malformed line: ###25168125
# Skipping malformed line: ###24834865
# Skipping malformed line: ###25045857
# Skipping malformed line: ###25503546
# Skipping malformed line: ###24481719
# Skipping malformed line: ###25294746
# Skipping malformed line: ###25811395
# Skipping malformed line: ###24417410
# Skipping malformed line: ###24988121
# Skipping malformed line: ###25886894
# Skipping malformed line: ###24907147
# Skipping malformed line: ###25201722
# Skipping malformed line: ###24522442
# Skipping malformed line: ###25988461
# Skipping malformed line: ###24346384
# Skipping malformed line: ###25040945
# Skipping malformed line: ###24446891
# Skipping malformed line: ###25408736
# Skipping malformed line: ###24884670
# Skipping malformed line: ###24672936
# Skipping malformed line: ###25476448
# Skipping malformed line: ###24862923
# Skipping malformed line: ###25330631
# Skipping malformed line: ###24912059
# Skipping malformed line: ###25575420
# Skipping malformed line: ###24912486
# Skipping malformed line: ###25454283
# Skipping malformed line: ###25229916
# Skipping malformed line: ###24996842
# Skipping malformed line: ###24714011
# Skipping malformed line: ###24485000
# Skipping malformed line: ###25564317
# Skipping malformed line: ###24667035
# Skipping malformed line: ###25605211
# Skipping malformed line: ###24528690
# Skipping malformed line: ###25491069
# Skipping malformed line: ###24555753
# Skipping malformed line: ###25631970
# Skipping malformed line: ###24710974
# Skipping malformed line: ###24256171
# Skipping malformed line: ###25207986
# Skipping malformed line: ###24965834
# Skipping malformed line: ###25341682
# Skipping malformed line: ###25151920
# Skipping malformed line: ###24971661
# Skipping malformed line: ###25240630
# Skipping malformed line: ###25245213
# Skipping malformed line: ###25171686
# Skipping malformed line: ###24225205
# Skipping malformed line: ###25397860
# Skipping malformed line: ###25916220
# Skipping malformed line: ###24399630
# Skipping malformed line: ###25902844
# Skipping malformed line: ###24646819
# Skipping malformed line: ###24405160
# Skipping malformed line: ###25619518
# Skipping malformed line: ###25322766
# Skipping malformed line: ###25188488
# Skipping malformed line: ###25233157
# Skipping malformed line: ###24467802
# Skipping malformed line: ###25103148
# Skipping malformed line: ###24694769
# Skipping malformed line: ###24730575
# Skipping malformed line: ###24670140
# Skipping malformed line: ###26209030
# Skipping malformed line: ###24787564
# Skipping malformed line: ###25794220
# Skipping malformed line: ###25104523
# Skipping malformed line: ###24947808
# Skipping malformed line: ###25247709
# Skipping malformed line: ###24710917
# Skipping malformed line: ###25791056
# Skipping malformed line: ###24450608
# Skipping malformed line: ###25552609
# Skipping malformed line: ###24975713
# Skipping malformed line: ###25358424
# Skipping malformed line: ###25325609
# Skipping malformed line: ###24547757
# Skipping malformed line: ###25460339
# Skipping malformed line: ###24682966
# Skipping malformed line: ###25973563
# Skipping malformed line: ###24510656
# Skipping malformed line: ###24346096
# Skipping malformed line: ###25248764
# Skipping malformed line: ###25335327
# Skipping malformed line: ###25656074
# Skipping malformed line: ###25106783
# Skipping malformed line: ###24268977
# Skipping malformed line: ###25448672
# Skipping malformed line: ###25539989
# Skipping malformed line: ###25370155
# Skipping malformed line: ###24323795
# Skipping malformed line: ###25964246
# Skipping malformed line: ###24714097
# Skipping malformed line: ###24884885
# Skipping malformed line: ###25043754
# Skipping malformed line: ###25155998
# Skipping malformed line: ###25078976
# Skipping malformed line: ###25467591
# Skipping malformed line: ###24680372
# Skipping malformed line: ###25377520
# Skipping malformed line: ###24809261
# Skipping malformed line: ###25908099
# Skipping malformed line: ###26047319
# Skipping malformed line: ###25085407
# Skipping malformed line: ###25762753
# Skipping malformed line: ###24969672
# Skipping malformed line: ###25295681
# Skipping malformed line: ###25348244
# Skipping malformed line: ###24219814
# Skipping malformed line: ###24259108
# Skipping malformed line: ###25261605
# Skipping malformed line: ###25349008
# Skipping malformed line: ###24226805
# Skipping malformed line: ###25335244
# Skipping malformed line: ###25147070
# Skipping malformed line: ###25425136
# Skipping malformed line: ###25260214
# Skipping malformed line: ###25564570
# Skipping malformed line: ###24795200
# Skipping malformed line: ###25741444
# Skipping malformed line: ###25524686
# Skipping malformed line: ###24549033
# Skipping malformed line: ###24707819
# Skipping malformed line: ###26189067
# Skipping malformed line: ###25599828
# Skipping malformed line: ###25896457
# Skipping malformed line: ###24314586
# Skipping malformed line: ###25283697
# Skipping malformed line: ###25170938
# Skipping malformed line: ###24503140
# Skipping malformed line: ###25055754
# Skipping malformed line: ###25653254
# Skipping malformed line: ###24867633
# Skipping malformed line: ###25654524
# Skipping malformed line: ###25125053
# Skipping malformed line: ###25200415
# Skipping malformed line: ###24578164
# Skipping malformed line: ###26198966
# Skipping malformed line: ###24433926
# Skipping malformed line: ###24330706
# Skipping malformed line: ###24819566
# Skipping malformed line: ###25128211
# Skipping malformed line: ###25877748
# Skipping malformed line: ###24283806
# Skipping malformed line: ###24966150
# Skipping malformed line: ###24806159
# Skipping malformed line: ###24266309
# Skipping malformed line: ###24607797
# Skipping malformed line: ###25294611
# Skipping malformed line: ###24330904
# Skipping malformed line: ###24461162
# Skipping malformed line: ###25452071
# Skipping malformed line: ###25106493
# Skipping malformed line: ###25185212
# Skipping malformed line: ###25007693
# Skipping malformed line: ###24460545
# Skipping malformed line: ###24758075
# Skipping malformed line: ###24866574
# Skipping malformed line: ###25523634
# Skipping malformed line: ###24745852
# Skipping malformed line: ###24888284
# Skipping malformed line: ###24560970
# Skipping malformed line: ###25863847
# Skipping malformed line: ###24598244
# Skipping malformed line: ###24896141
# Skipping malformed line: ###24295013
# Skipping malformed line: ###24382118
# Skipping malformed line: ###25465217
# Skipping malformed line: ###24796937
# Skipping malformed line: ###25789519
# Skipping malformed line: ###25669083
# Skipping malformed line: ###25538277
# Skipping malformed line: ###24882900
# Skipping malformed line: ###25141526
# Skipping malformed line: ###25169962
# Skipping malformed line: ###24530759
# Skipping malformed line: ###24277961
# Skipping malformed line: ###24753128
# Skipping malformed line: ###25270857
# Skipping malformed line: ###25006684
# Skipping malformed line: ###24376009
# Skipping malformed line: ###25882764
# Skipping malformed line: ###25150607
# Skipping malformed line: ###25981818
# Skipping malformed line: ###26290082
# Skipping malformed line: ###25359128
# Skipping malformed line: ###24913337
# Skipping malformed line: ###24689247
# Skipping malformed line: ###26258451
# Skipping malformed line: ###25029833
# Skipping malformed line: ###24411682
# Skipping malformed line: ###25838249
# Skipping malformed line: ###25593483
# Skipping malformed line: ###24607075
# Skipping malformed line: ###25326876
# Skipping malformed line: ###24502652
# Skipping malformed line: ###25295770
# Skipping malformed line: ###25062857
# Skipping malformed line: ###24726247
# Skipping malformed line: ###24527996
# Skipping malformed line: ###25726404
# Skipping malformed line: ###25311446
# Skipping malformed line: ###24923533
# Skipping malformed line: ###26206644
# Skipping malformed line: ###25645425
# Skipping malformed line: ###25417983
# Skipping malformed line: ###24985574
# Skipping malformed line: ###24248687
# Skipping malformed line: ###25581656
# Skipping malformed line: ###24656314
# Skipping malformed line: ###25862517
# Skipping malformed line: ###25835472
# Skipping malformed line: ###25677337
# Skipping malformed line: ###24998106
# Skipping malformed line: ###24825167
# Skipping malformed line: ###24886151
# Skipping malformed line: ###25197921
# Skipping malformed line: ###25140908
# Skipping malformed line: ###24317176
# Skipping malformed line: ###24880449
# Skipping malformed line: ###24708570
# Skipping malformed line: ###24841020
# Skipping malformed line: ###24507221
# Skipping malformed line: ###24620855
# Skipping malformed line: ###24622806
# Skipping malformed line: ###25187345
# Skipping malformed line: ###25037139
# Skipping malformed line: ###24854303
# Skipping malformed line: ###24865945
# Skipping malformed line: ###25552421
# Skipping malformed line: ###25168278
# Skipping malformed line: ###24252587
# Skipping malformed line: ###26437499
# Skipping malformed line: ###25138802
# Skipping malformed line: ###25052061
# Skipping malformed line: ###25149556
# Skipping malformed line: ###24702445
# Skipping malformed line: ###24749723
# Skipping malformed line: ###24855193
# Skipping malformed line: ###25736126
# Skipping malformed line: ###24548730
# Skipping malformed line: ###25134740
# Skipping malformed line: ###25330671
# Skipping malformed line: ###25833781
# Skipping malformed line: ###24467917
# Skipping malformed line: ###25673981
# Skipping malformed line: ###25420207
# Skipping malformed line: ###24449105
# Skipping malformed line: ###24571886
# Skipping malformed line: ###25527747
# Skipping malformed line: ###24999157
# Skipping malformed line: ###25867659
# Skipping malformed line: ###24682844
# Skipping malformed line: ###25185149
# Skipping malformed line: ###25524534
# Skipping malformed line: ###25563643
# Skipping malformed line: ###24519563
# Skipping malformed line: ###25543688
# Skipping malformed line: ###25472660
# Skipping malformed line: ###25010303
# Skipping malformed line: ###24906043
# Skipping malformed line: ###25976690
# Skipping malformed line: ###24502231
# Skipping malformed line: ###26109581
# Skipping malformed line: ###24491134
# Skipping malformed line: ###25189175
# Skipping malformed line: ###24474434
# Skipping malformed line: ###25698197
# Skipping malformed line: ###25265492
# Skipping malformed line: ###25807815
# Skipping malformed line: ###25472936
# Skipping malformed line: ###25416400
# Skipping malformed line: ###25503550
# Skipping malformed line: ###24899589
# Skipping malformed line: ###24405734
# Skipping malformed line: ###25138332
# Skipping malformed line: ###24388090
# Skipping malformed line: ###24856557
# Skipping malformed line: ###24634205
# Skipping malformed line: ###25140763
# Skipping malformed line: ###24751502
# Skipping malformed line: ###24266715
# Skipping malformed line: ###25517587
# Skipping malformed line: ###24885096
# Skipping malformed line: ###25118795
# Skipping malformed line: ###25211369
# Skipping malformed line: ###26089047
# Skipping malformed line: ###25620217
# Skipping malformed line: ###26159065
# Skipping malformed line: ###25208030
# Skipping malformed line: ###24280856
# Skipping malformed line: ###24532596
# Skipping malformed line: ###25112372
# Skipping malformed line: ###25059094
# Skipping malformed line: ###25545238
# Skipping malformed line: ###24474180
# Skipping malformed line: ###24310443
# Skipping malformed line: ###24480179
# Skipping malformed line: ###24460863
# Skipping malformed line: ###24690159
# Skipping malformed line: ###25541942
# Skipping malformed line: ###25811824
# Skipping malformed line: ###24495883
# Skipping malformed line: ###24670677
# Skipping malformed line: ###24313178
# Skipping malformed line: ###25371291
# Skipping malformed line: ###25065086
# Skipping malformed line: ###25518508
# Skipping malformed line: ###24680359
# Skipping malformed line: ###25175696
# Skipping malformed line: ###24838360
# Skipping malformed line: ###24384657
# Skipping malformed line: ###24509214
# Skipping malformed line: ###25468084
# Skipping malformed line: ###24368354
# Skipping malformed line: ###24786946
# Skipping malformed line: ###25204404
# Skipping malformed line: ###25992505
# Skipping malformed line: ###25047497
# Skipping malformed line: ###24487961
# Skipping malformed line: ###24368363
# Skipping malformed line: ###24899557
# Skipping malformed line: ###24811226
# Skipping malformed line: ###25217875
# Skipping malformed line: ###24300630
# Skipping malformed line: ###25321951
# Skipping malformed line: ###24905929
# Skipping malformed line: ###25864240
# Skipping malformed line: ###24509967
# Skipping malformed line: ###24479702
# Skipping malformed line: ###24520664
# Skipping malformed line: ###25156340
# Skipping malformed line: ###24480603
# Skipping malformed line: ###25287325
# Skipping malformed line: ###25378208
# Skipping malformed line: ###24938502
# Skipping malformed line: ###24998039
# Skipping malformed line: ###24467770
# Skipping malformed line: ###25927562
# Skipping malformed line: ###25060189
# Skipping malformed line: ###24595578
# Skipping malformed line: ###25878175
# Skipping malformed line: ###24981605
# Skipping malformed line: ###25301344
# Skipping malformed line: ###24535643
# Skipping malformed line: ###24693675
# Skipping malformed line: ###25244402
# Skipping malformed line: ###25868203
# Skipping malformed line: ###24906174
# Skipping malformed line: ###24680796
# Skipping malformed line: ###24255998
# Skipping malformed line: ###25450583
# Skipping malformed line: ###24612754
# Skipping malformed line: ###26079801
# Skipping malformed line: ###24530350
# Skipping malformed line: ###24489043
# Skipping malformed line: ###26152131
# Skipping malformed line: ###24950747
# Skipping malformed line: ###24259265
# Skipping malformed line: ###25193529
# Skipping malformed line: ###24940942
# Skipping malformed line: ###25952354
# Skipping malformed line: ###25630368
# Skipping malformed line: ###24311515
# Skipping malformed line: ###24224396
# Skipping malformed line: ###25597457
# Skipping malformed line: ###25066921
# Skipping malformed line: ###24730708
# Skipping malformed line: ###24813196
# Skipping malformed line: ###24628789
# Skipping malformed line: ###24553033
# Skipping malformed line: ###24980467
# Skipping malformed line: ###24400838
# Skipping malformed line: ###26406148
# Skipping malformed line: ###25632741
# Skipping malformed line: ###24880672
# Skipping malformed line: ###24385406
# Skipping malformed line: ###24309370
# Skipping malformed line: ###24948345
# Skipping malformed line: ###25756419
# Skipping malformed line: ###24981955
# Skipping malformed line: ###25425736
# Skipping malformed line: ###24998546
# Skipping malformed line: ###24274836
# Skipping malformed line: ###24796766
# Skipping malformed line: ###24268677
# Skipping malformed line: ###24925094
# Skipping malformed line: ###24383496
# Skipping malformed line: ###24903230
# Skipping malformed line: ###25586295
# Skipping malformed line: ###25234932
# Skipping malformed line: ###24447425
# Skipping malformed line: ###24421213
# Skipping malformed line: ###25151225
# Skipping malformed line: ###25011952
# Skipping malformed line: ###25594912
# Skipping malformed line: ###25321620
# Skipping malformed line: ###24343071
# Skipping malformed line: ###25119950
# Skipping malformed line: ###24997476
# Skipping malformed line: ###24983989
# Skipping malformed line: ###25611313
# Skipping malformed line: ###24321456
# Skipping malformed line: ###25195970
# Skipping malformed line: ###25156987
# Skipping malformed line: ###25109239
# Skipping malformed line: ###24244449
# Skipping malformed line: ###24274210
# Skipping malformed line: ###24836780
# Skipping malformed line: ###24621976
# Skipping malformed line: ###25886930
# Skipping malformed line: ###24375296
# Skipping malformed line: ###24355659
# Skipping malformed line: ###24877717
# Skipping malformed line: ###25274892
# Skipping malformed line: ###24499060
# Skipping malformed line: ###25415805
# Skipping malformed line: ###25300221
# Skipping malformed line: ###24925270
# Skipping malformed line: ###24468078
# Skipping malformed line: ###24652032
# Skipping malformed line: ###24332139
# Skipping malformed line: ###24552826
# Skipping malformed line: ###25262251
# Skipping malformed line: ###24518152
# Skipping malformed line: ###24766760
# Skipping malformed line: ###25462647
# Skipping malformed line: ###24619298
# ...
# Skipping malformed line: ###24281461
# Skipping malformed line: ###25336596
# Skipping malformed line: ###25146960
# Skipping malformed line: ###24731671
# Skipping malformed line: ###25828636
# Skipping malformed line: ###25711329
# Skipping malformed line: ###24854041
# Skipping malformed line: ###25185456
# Skipping malformed line: ###25932700
# Skipping malformed line: ###24821885
# Skipping malformed line: ###25476698
# Skipping malformed line: ###25707477
# Skipping malformed line: ###25079863
# Skipping malformed line: ###24366852
# Skipping malformed line: ###24573620
# Skipping malformed line: ###24752957
# Skipping malformed line: ###24257390
# Skipping malformed line: ###25104617
# Skipping malformed line: ###25322606
# Skipping malformed line: ###25514585
# Skipping malformed line: ###25256660
# Skipping malformed line: ###24374004
# Skipping malformed line: ###24488447
# Skipping malformed line: ###24962875
# Skipping malformed line: ###26027245
# Skipping malformed line: ###25831644
# Skipping malformed line: ###24249817
# Skipping malformed line: ###25201508
# Skipping malformed line: ###24268548
# Skipping malformed line: ###24220913
# Skipping malformed line: ###25234603
# Skipping malformed line: ###24246210
# Skipping malformed line: ###24884415
# Skipping malformed line: ###26241433
# Skipping malformed line: ###25211767
# Skipping malformed line: ###24320206
# Skipping malformed line: ###24898857
# Skipping malformed line: ###24266670
# Skipping malformed line: ###24673650
# Skipping malformed line: ###25325193
# Skipping malformed line: ###24488359
# Skipping malformed line: ###25140337
# Skipping malformed line: ###24972789
# Skipping malformed line: ###25086821
# Skipping malformed line: ###26009229
# Skipping malformed line: ###25501607
# Skipping malformed line: ###24384865
# Skipping malformed line: ###24500060
# Skipping malformed line: ###25263393
# Skipping malformed line: ###24477618
# Skipping malformed line: ###24654201
# Skipping malformed line: ###24816809
# Skipping malformed line: ###25815420
# Skipping malformed line: ###24983382
# Skipping malformed line: ###25533656
# Skipping malformed line: ###24527599
# Skipping malformed line: ###24928217
# Skipping malformed line: ###25367539
# Skipping malformed line: ###25173752
# Skipping malformed line: ###24636395
# Skipping malformed line: ###25475464
# Skipping malformed line: ###24857356
# Skipping malformed line: ###24225010
# Skipping malformed line: ###25877710
# Skipping malformed line: ###25073921
# Skipping malformed line: ###24240647
# Skipping malformed line: ###25625133
# Skipping malformed line: ###24445278
# Skipping malformed line: ###25171966
# Skipping malformed line: ###26390724
# Skipping malformed line: ###24378018
# Skipping malformed line: ###24895001
# Skipping malformed line: ###24748530
# Skipping malformed line: ###25241755
# Skipping malformed line: ###24697586
# Skipping malformed line: ###25881035
# Skipping malformed line: ###24874401
# Skipping malformed line: ###25041994
# Skipping malformed line: ###24290404
# Skipping malformed line: ###25125229
# Skipping malformed line: ###24939043
# Skipping malformed line: ###26244877
# Skipping malformed line: ###24255129
# Skipping malformed line: ###24956042
# Skipping malformed line: ###24332142
# Skipping malformed line: ###25439413
# Skipping malformed line: ###25197740
# Skipping malformed line: ###24408214
# Skipping malformed line: ###24740312
# Skipping malformed line: ###25730227
# Skipping malformed line: ###25381314
# Skipping malformed line: ###25146918
# Skipping malformed line: ###24239341
# Skipping malformed line: ###24678955
# Skipping malformed line: ###24355040
# Skipping malformed line: ###24450370
# Skipping malformed line: ###25304996
# Skipping malformed line: ###25470476
# Skipping malformed line: ###24991030
# Skipping malformed line: ###25359384
# Skipping malformed line: ###25640408
# Skipping malformed line: ###24678807
# Skipping malformed line: ###24320832
# Skipping malformed line: ###24767671
# Skipping malformed line: ###25749601
# Skipping malformed line: ###24840230
# Skipping malformed line: ###24385636
# Skipping malformed line: ###24908910
# Skipping malformed line: ###25027304
# Skipping malformed line: ###25266433
# Skipping malformed line: ###25009402
# Skipping malformed line: ###25098611
# Skipping malformed line: ###25266981
# Skipping malformed line: ###25416514
# Skipping malformed line: ###25278139
# Skipping malformed line: ###25310146
# Skipping malformed line: ###25981049
# Skipping malformed line: ###24650400
# Skipping malformed line: ###25171575
# Skipping malformed line: ###24781718
# Skipping malformed line: ###25345257
# Skipping malformed line: ###25341453
# Skipping malformed line: ###24237724
# Skipping malformed line: ###24328607
# Skipping malformed line: ###24334800
# Skipping malformed line: ###25233647
# Skipping malformed line: ###24793078
# Skipping malformed line: ###24999797
# Skipping malformed line: ###24821974
# Skipping malformed line: ###24506479
# Skipping malformed line: ###25635593
# Skipping malformed line: ###24627921
# Skipping malformed line: ###24622804
# Skipping malformed line: ###25643851
# Skipping malformed line: ###24928218
# Skipping malformed line: ###26085529
# Skipping malformed line: ###26026615
# Skipping malformed line: ###25497262
# Skipping malformed line: ###25437725
# Skipping malformed line: ###25061127
# Skipping malformed line: ###24693959
# Skipping malformed line: ###25222672
# Skipping malformed line: ###25526101
# Skipping malformed line: ###25300916
# Skipping malformed line: ###25592552
# Skipping malformed line: ###24585202
# Skipping malformed line: ###24806568
# Skipping malformed line: ###25038208
# Skipping malformed line: ###25398799
# Skipping malformed line: ###25773757
# Skipping malformed line: ###24943829
# Skipping malformed line: ###24994476
# Skipping malformed line: ###25236776
# Skipping malformed line: ###26054119
# Skipping malformed line: ###24999283
# Skipping malformed line: ###25039978
# Skipping malformed line: ###25315937
# Skipping malformed line: ###25355716
# Skipping malformed line: ###24273022
# Skipping malformed line: ###24480909
# Skipping malformed line: ###25694008
# Skipping malformed line: ###24555585
# Skipping malformed line: ###24618336
# Skipping malformed line: ###26073354
# Skipping malformed line: ###25456099
# Skipping malformed line: ###24341511
# Skipping malformed line: ###25247950
# Skipping malformed line: ###26442399
# Skipping malformed line: ###24634333
# Skipping malformed line: ###25467005
# Skipping malformed line: ###25344328
# Skipping malformed line: ###25407227
# Skipping malformed line: ###24372521
# Skipping malformed line: ###24886647
# Skipping malformed line: ###24769601
# Skipping malformed line: ###24836655
# Skipping malformed line: ###24380874
# Skipping malformed line: ###25444717
# Skipping malformed line: ###24814090
# Skipping malformed line: ###24613188
# Skipping malformed line: ###25261967
# Skipping malformed line: ###25602634
# Skipping malformed line: ###24253484
# Skipping malformed line: ###24471747
# Skipping malformed line: ###24763187
# Skipping malformed line: ###24774351
# Skipping malformed line: ###25730446
# Skipping malformed line: ###24559812
# Skipping malformed line: ###25557807
# Skipping malformed line: ###25303096
# Skipping malformed line: ###25009196
# Skipping malformed line: ###25284751
# Skipping malformed line: ###24583546
# Skipping malformed line: ###25088860
# Skipping malformed line: ###24694530
# Skipping malformed line: ###24918122
# Skipping malformed line: ###25102458
# Skipping malformed line: ###25041182
# Skipping malformed line: ###25242051
# Skipping malformed line: ###25769361
# Skipping malformed line: ###25970009
# Skipping malformed line: ###25460174
# Skipping malformed line: ###25738668
# Skipping malformed line: ###25968407
# Skipping malformed line: ###24526592
# Skipping malformed line: ###25876351
# Skipping malformed line: ###25055027
# Skipping malformed line: ###24417710
# Skipping malformed line: ###24499493
# Skipping malformed line: ###25828372
# Skipping malformed line: ###25230136
# Skipping malformed line: ###25233644
# Skipping malformed line: ###25316904
# Skipping malformed line: ###24696010
# Skipping malformed line: ###24282495
# Skipping malformed line: ###25623680
# Skipping malformed line: ###26075373
# Skipping malformed line: ###24934402
# Skipping malformed line: ###24617231
# Skipping malformed line: ###25370913
# Skipping malformed line: ###26001837
# Skipping malformed line: ###24839144
# Skipping malformed line: ###24867069
# Skipping malformed line: ###25286684
# Skipping malformed line: ###25015006
# Skipping malformed line: ###24777901
# Skipping malformed line: ###24386744
# Skipping malformed line: ###25444576
# Skipping malformed line: ###24997826
# Skipping malformed line: ###25601538
# Skipping malformed line: ###24708735
# Skipping malformed line: ###25361980
# Skipping malformed line: ###24841548
# Skipping malformed line: ###24947633
# Skipping malformed line: ###25280578
# Skipping malformed line: ###25010300
# Skipping malformed line: ###24819981
# Skipping malformed line: ###25624196
# Skipping malformed line: ###24576395
# Skipping malformed line: ###25789518
# Skipping malformed line: ###25055716
# Skipping malformed line: ###24614337
# Skipping malformed line: ###26148930
# Skipping malformed line: ###25862743
# Skipping malformed line: ###24700493
# Skipping malformed line: ###24614572
# Skipping malformed line: ###25243546
# Skipping malformed line: ###25084699
# Skipping malformed line: ###25565416
# Skipping malformed line: ###25060015
# Skipping malformed line: ###25527751
# Skipping malformed line: ###24434070
# Skipping malformed line: ###24835837
# Skipping malformed line: ###26218728
# Skipping malformed line: ###24445981
# Skipping malformed line: ###24703570
# Skipping malformed line: ###24752034
# Skipping malformed line: ###26255456
# Skipping malformed line: ###24330220
# Skipping malformed line: ###24937476
# Skipping malformed line: ###24947034
# Skipping malformed line: ###24517384
# Skipping malformed line: ###24755339
# Skipping malformed line: ###24582087
# Skipping malformed line: ###24931747
# Skipping malformed line: ###24776754
# Skipping malformed line: ###25441435
# Skipping malformed line: ###24892803
# Skipping malformed line: ###24931591
# Skipping malformed line: ###24302181
# Skipping malformed line: ###24831368
# Skipping malformed line: ###24508386
# Skipping malformed line: ###25171741
# Skipping malformed line: ###25117817
# Skipping malformed line: ###24655228
# Skipping malformed line: ###25585082
# Skipping malformed line: ###25496482
# Skipping malformed line: ###24532502
# Skipping malformed line: ###24635773
# Skipping malformed line: ###24484545
# Skipping malformed line: ###25038015
# Skipping malformed line: ###24422892
# Skipping malformed line: ###24365774
# Skipping malformed line: ###24454949
# Skipping malformed line: ###24276777
# Skipping malformed line: ###25204642
# Skipping malformed line: ###24237751
# Skipping malformed line: ###24310444
# Skipping malformed line: ###25411294
# Skipping malformed line: ###26255475
# Skipping malformed line: ###25409738
# Skipping malformed line: ###24766747
# Skipping malformed line: ###24697580
# Skipping malformed line: ###24354968
# Skipping malformed line: ###24769270
# Skipping malformed line: ###24998572
# Skipping malformed line: ###24508362
# Skipping malformed line: ###25549485
# Skipping malformed line: ###25444416
# Skipping malformed line: ###25140033
# Skipping malformed line: ###24354930
# Skipping malformed line: ###25975632
# Skipping malformed line: ###24308189
# Skipping malformed line: ###24386406
# Skipping malformed line: ###25470094
# Skipping malformed line: ###25616350
# Skipping malformed line: ###24755046
# Skipping malformed line: ###24373555
# Skipping malformed line: ###24423149
# Skipping malformed line: ###24483103
# Skipping malformed line: ###26182747
# Skipping malformed line: ###24660950
# Skipping malformed line: ###24279429
# Skipping malformed line: ###24450891
# Skipping malformed line: ###24335927
# Skipping malformed line: ###25198224
# Skipping malformed line: ###25070546
# Skipping malformed line: ###25483563
# Skipping malformed line: ###25672160
# Skipping malformed line: ###24783602
# Skipping malformed line: ###26237980
# Skipping malformed line: ###24945241
# Skipping malformed line: ###24372522
# Skipping malformed line: ###25854015
# Skipping malformed line: ###25961136
# Skipping malformed line: ###24909836
# Skipping malformed line: ###25232263
# Skipping malformed line: ###25128068
# Skipping malformed line: ###24515352
# Skipping malformed line: ###25259781
# Skipping malformed line: ###24907502
# Skipping malformed line: ###24740207
# Skipping malformed line: ###24285457
# Skipping malformed line: ###26063762
# Skipping malformed line: ###24987970
# Skipping malformed line: ###25608899
# Skipping malformed line: ###24925713
# Skipping malformed line: ###24980650
# Skipping malformed line: ###25533442
# Skipping malformed line: ###26227101
# Skipping malformed line: ###24528484
# Skipping malformed line: ###24928338
# Skipping malformed line: ###25656375
# Skipping malformed line: ###24522441
# Skipping malformed line: ###24857519
# Skipping malformed line: ###24442226
# Skipping malformed line: ###24983279
# Skipping malformed line: ###24635755
# Skipping malformed line: ###25975558
# Skipping malformed line: ###25123549
# Skipping malformed line: ###24764200
# Skipping malformed line: ###24565713
# Skipping malformed line: ###24766732
# Skipping malformed line: ###26271061
# Skipping malformed line: ###24267123
# Skipping malformed line: ###25876640
# Skipping malformed line: ###24818590
# Skipping malformed line: ###25020155
# Skipping malformed line: ###25352870
# Skipping malformed line: ###25343191
# Skipping malformed line: ###25465416
# Skipping malformed line: ###25265887
# Skipping malformed line: ###24438128
# Skipping malformed line: ###24555620
# Skipping malformed line: ###24275482
# Skipping malformed line: ###24414439
# Skipping malformed line: ###24988105
# Skipping malformed line: ###26014298
# Skipping malformed line: ###26005977
# Skipping malformed line: ###24809482
# Skipping malformed line: ###25566703
# Skipping malformed line: ###24834811
# Skipping malformed line: ###25624076
# Skipping malformed line: ###24819506
# Skipping malformed line: ###25079090
# Skipping malformed line: ###24654220
# Skipping malformed line: ###25619692
# Skipping malformed line: ###25317794
# Skipping malformed line: ###25057155
# Skipping malformed line: ###25400472
# Skipping malformed line: ###25769076
# Skipping malformed line: ###24577643
# Skipping malformed line: ###24797228
# Skipping malformed line: ###24880194
# Skipping malformed line: ###24582111
# Skipping malformed line: ###24268702
# Skipping malformed line: ###25688605
# Skipping malformed line: ###24911427
# Skipping malformed line: ###25539672
# Skipping malformed line: ###24283167
# Skipping malformed line: ###25782985
# Skipping malformed line: ###24565387
# Skipping malformed line: ###25266473
# Skipping malformed line: ###24550581
# Skipping malformed line: ###25410648
# Skipping malformed line: ###24626733
# Skipping malformed line: ###26165528
# Skipping malformed line: ###25930719
# Skipping malformed line: ###24762413
# Skipping malformed line: ###26164864
# Skipping malformed line: ###25065692
# Skipping malformed line: ###25901427
# Skipping malformed line: ###24742740
# Skipping malformed line: ###24751173
# Skipping malformed line: ###24997634
# Skipping malformed line: ###24958780
# Skipping malformed line: ###24976291
# Skipping malformed line: ###25160492
# Skipping malformed line: ###25178073
# Skipping malformed line: ###24417786
# Skipping malformed line: ###25011647
# Skipping malformed line: ###25326750
# Skipping malformed line: ###24785854
# Skipping malformed line: ###24991973
# Skipping malformed line: ###25636293
# Skipping malformed line: ###25942722
# Skipping malformed line: ###24581245
# Skipping malformed line: ###25458333
# Skipping malformed line: ###25233654
# Skipping malformed line: ###25212696
# Skipping malformed line: ###26325557
# Skipping malformed line: ###25437223
# Skipping malformed line: ###25427324
# Skipping malformed line: ###25417309
# Skipping malformed line: ###25195125
# Skipping malformed line: ###25342855
# Skipping malformed line: ###25504267
# Skipping malformed line: ###25028463
# Skipping malformed line: ###24261927
# Label Mapping: {'BACKGROUND': 0, 'CONCLUSIONS': 1, 'METHODS': 2, 'OBJECTIVE': 3, 'RESULTS': 4}

# %% [markdown]
# Step 3: Baseline Model (Naïve Bayes + TF-IDF)

# %%
# Apply preprocessing (SpaCy for stopword removal, lemmatization)
nlp = spacy.load("en_core_web_sm")

def preprocess_text(text):
    doc = nlp(text.lower())
    tokens = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(tokens)

# Preprocess data
train_sentences_clean = [preprocess_text(text) for text in train_sentences]
test_sentences_clean = [preprocess_text(text) for text in test_sentences]

# TF-IDF Vectorization
vectorizer = TfidfVectorizer(ngram_range=(1,3))
X_train_tfidf = vectorizer.fit_transform(train_sentences_clean)
X_test_tfidf = vectorizer.transform(test_sentences_clean)

# Train Naïve Bayes Model
from sklearn.naive_bayes import MultinomialNB
nb_model = MultinomialNB()
nb_model.fit(X_train_tfidf, train_labels_encoded)

# Evaluate
nb_accuracy = nb_model.score(X_test_tfidf, test_labels_encoded)
print(f"Naïve Bayes Accuracy: {nb_accuracy * 100:.2f}%")

# %% [markdown]
# Step 4: Conv1D with Token Embedding

# %%
# Tokenize Text
tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>")
tokenizer.fit_on_texts(train_sentences)
train_sequences = tokenizer.texts_to_sequences(train_sentences)
test_sequences = tokenizer.texts_to_sequences(test_sentences)

# Apply Padding
MAX_SEQUENCE_LENGTH = 100
train_padded = pad_sequences(train_sequences, maxlen=MAX_SEQUENCE_LENGTH)
test_padded = pad_sequences(test_sequences, maxlen=MAX_SEQUENCE_LENGTH)

# Conv1D Model
conv1d_model = Sequential([
    Embedding(input_dim=10000, output_dim=100, input_length=MAX_SEQUENCE_LENGTH),
    Conv1D(128, 5, activation='relu'),
    GlobalMaxPooling1D(),
    Dense(64, activation='relu'),
    Dense(len(label_mapping), activation='softmax')
])

conv1d_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train
conv1d_model.fit(train_padded, np.array(train_labels_encoded), epochs=5, batch_size=32, validation_data=(test_padded, np.array(test_labels_encoded)))

# Evaluate
conv1d_accuracy = conv1d_model.evaluate(test_padded, np.array(test_labels_encoded))[1]
print(f"Conv1D Accuracy: {conv1d_accuracy * 100:.2f}%")

# %% [markdown]
# Step 5: Pretrained Feature Extractor (GloVe)

# %%
# Load GloVe
glove_path = "glove.6B.100d.txt"
embedding_index = {}
with open(glove_path, "r", encoding="utf-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype="float32")
        embedding_index[word] = coefs

# Create Embedding Matrix
embedding_matrix = np.zeros((10000, 100))
for word, i in tokenizer.word_index.items():
    if i < 10000:
        embedding_vector = embedding_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector

# Modify Conv1D Model with Pretrained Embeddings
conv1d_model.layers[0].set_weights([embedding_matrix])
conv1d_model.layers[0].trainable = False

# %% [markdown]
# Step 6: Hybrid Model (BERT + Conv1D)

# %%
# Load BERT
bert_model = BertModel.from_pretrained("bert-base-uncased")
bert_tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# Extract BERT Embeddings
def extract_bert_embeddings(texts):
    encodings = bert_tokenizer(texts, padding="max_length", truncation=True, max_length=128, return_tensors="pt")
    with torch.no_grad():
        outputs = bert_model(input_ids=encodings["input_ids"], attention_mask=encodings["attention_mask"])
    return outputs.last_hidden_state[:, 0, :].cpu().numpy()

train_bert_embeddings = extract_bert_embeddings(train_sentences)
test_bert_embeddings = extract_bert_embeddings(test_sentences)

# Reshape for Conv1D
train_bert_reshaped = np.expand_dims(train_bert_embeddings, axis=-1)
test_bert_reshaped = np.expand_dims(test_bert_embeddings, axis=-1)

# Hybrid Model
hybrid_model = Sequential([
    Input(shape=(train_bert_embeddings.shape[1], 1)),
    Conv1D(128, 3, activation='relu'),
    GlobalMaxPooling1D(),
    Dense(64, activation='relu'),
    Dense(len(label_mapping), activation='softmax')
])

hybrid_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train
hybrid_model.fit(train_bert_reshaped, np.array(train_labels_encoded), epochs=5, batch_size=32, validation_data=(test_bert_reshaped, np.array(test_labels_encoded)))

# Evaluate
hybrid_accuracy = hybrid_model.evaluate(test_bert_reshaped, np.array(test_labels_encoded))[1]
print(f"Hybrid Model (BERT + Conv1D) Accuracy: {hybrid_accuracy * 100:.2f}%")
